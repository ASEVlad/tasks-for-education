# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('D:/Prog/ML/Coursera/Yandex rus/dota/features.csv')

# %%
data.head()
# Out:
#    match_id  start_time  lobby_type  r1_hero  r1_level  r1_xp  r1_gold  r1_lh  \
# 0         0  1430198770           7       11         5   2098     1489     20
# 1         1  1430220345           0       42         4   1188     1033      9
# 2         2  1430227081           7       33         4   1319     1270     22
# 3         3  1430263531           1       29         4   1779     1056     14
# 4         4  1430282290           7       13         4   1431     1090      8
#
#    r1_kills  r1_deaths          ...           dire_boots_count  \
# 0         0          0          ...                          4
# 1         0          1          ...                          4
# 2         0          0          ...                          4
# 3         0          0          ...                          4
# 4         1          0          ...                          3
#
#    dire_ward_observer_count  dire_ward_sentry_count  dire_first_ward_time  \
# ...

# %%
pd.set_option('display.max_rows', 109)
pd.set_option('display.max_columns', 100)

# %%
data.head()
# Out:
#    match_id  start_time  lobby_type  r1_hero  r1_level  r1_xp  r1_gold  r1_lh  \
# 0         0  1430198770           7       11         5   2098     1489     20
# 1         1  1430220345           0       42         4   1188     1033      9
# 2         2  1430227081           7       33         4   1319     1270     22
# 3         3  1430263531           1       29         4   1779     1056     14
# 4         4  1430282290           7       13         4   1431     1090      8
#
#    r1_kills  r1_deaths  r1_items  r2_hero  r2_level  r2_xp  r2_gold  r2_lh  \
# 0         0          0         7       67         3    842      991     10
# 1         0          1        12       49         4   1596      993     10
# 2         0          0        12       98         3   1314      775      6
# 3         0          0         5       30         2    539      539      1
# 4         1          0         8       27         2    629      552      0
#
# ...

# %%
data.shape
# Out:
# (97230, 109)

# %%
data.columns
# Out:
# Index(['match_id', 'start_time', 'lobby_type', 'r1_hero', 'r1_level', 'r1_xp',
#        'r1_gold', 'r1_lh', 'r1_kills', 'r1_deaths',
#        ...
#        'dire_boots_count', 'dire_ward_observer_count',
#        'dire_ward_sentry_count', 'dire_first_ward_time', 'duration',
#        'radiant_win', 'tower_status_radiant', 'tower_status_dire',
#        'barracks_status_radiant', 'barracks_status_dire'],
#       dtype='object', length=109)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97230 entries, 0 to 97229
# Columns: 109 entries, match_id to barracks_status_dire
# dtypes: float64(12), int64(97)
# memory usage: 80.9 MB

# %%
data['radiant_win'] = data['radiant_win'].astype('bool')

# %%
data['radiant_win'][0]
# Out:
# True

# %%
data.describe()
# Out:
#             match_id    start_time    lobby_type       r1_hero      r1_level  \
# count   97230.000000  9.723000e+04  97230.000000  97230.000000  97230.000000
# mean    57185.416744  1.444232e+09      2.630999     51.517104      3.442672
# std     33007.123878  5.515393e+06      2.835761     32.564211      1.111741
# min         0.000000  1.430199e+09      0.000000      1.000000      0.000000
# 25%     28545.250000  1.440815e+09      1.000000     22.000000      3.000000
# 50%     57160.500000  1.446338e+09      1.000000     50.000000      3.000000
# 75%     85755.750000  1.448829e+09      7.000000     75.000000      4.000000
# max    114406.000000  1.450313e+09      7.000000    112.000000      6.000000
#
#               r1_xp       r1_gold         r1_lh      r1_kills     r1_deaths  \
# count  97230.000000  97230.000000  97230.000000  97230.000000  97230.000000
# mean    1233.405801   1147.899702     11.231996      0.357009      0.362285
# ...

# %%
data.describe(include='bool')
# Out:
#        radiant_win
# count        97230
# unique           2
# top           True
# freq         50414

# %%
data['radiant_win'].value_counts()
# Out:
# True     50414
# False    46816
# Name: radiant_win, dtype: int64

# %%
data['r1_level'].value_counts(normalize=True)
# Out:
# 3    0.325579
# 4    0.277548
# 5    0.195577
# 2    0.166523
# 1    0.021485
# 0    0.009400
# 6    0.003888
# Name: r1_level, dtype: float64

# %%
data['r1_level'].value_counts()
# Out:
# 3    31656
# 4    26986
# 5    19016
# 2    16191
# 1     2089
# 0      914
# 6      378
# Name: r1_level, dtype: int64

# %%
data = data.sort_values(by='r1_level', ascending=True)

# %%
data['r1_items'].mean()
# Out:
# 8.271315437622134

# %%
data[data['r1_items'] > 6]['r1_level'].mean()
# Out:
# 3.4250808910666968

# %%
data[(data['radiant_win']) & (data['r1_items'] > 6)]['r1_level'].mean()
# Out:
# 3.470668142483397

# %%
data[data['radiant_win']].mean()
# Out:
# match_id                       5.792637e+04
# start_time                     1.444330e+09
# lobby_type                     2.606260e+00
# r1_hero                        5.164115e+01
# r1_level                       3.482366e+00
# r1_xp                          1.260686e+03
# r1_gold                        1.189747e+03
# r1_lh                          1.171087e+01
# r1_kills                       4.087158e-01
# r1_deaths                      3.144563e-01
# r1_items                       8.399512e+00
# r2_hero                        5.190465e+01
# r2_level                       3.417027e+00
# r2_xp                          1.221837e+03
# r2_gold                        1.151569e+03
# r2_lh                          1.102692e+01
# r2_kills                       3.969136e-01
# r2_deaths                      3.135439e-01
# r2_items                       8.386619e+00
# r3_hero                        5.278556e+01
# r3_level                       3.395505e+00
# ...

# %%
data.mean()
# Out:
# match_id                       5.718542e+04
# start_time                     1.444232e+09
# lobby_type                     2.630999e+00
# r1_hero                        5.151710e+01
# r1_level                       3.442672e+00
# r1_xp                          1.233406e+03
# r1_gold                        1.147900e+03
# r1_lh                          1.123200e+01
# r1_kills                       3.570092e-01
# r1_deaths                      3.622853e-01
# r1_items                       8.271315e+00
# r2_hero                        5.218345e+01
# r2_level                       3.364661e+00
# r2_xp                          1.189224e+03
# r2_gold                        1.107864e+03
# r2_lh                          1.047175e+01
# r2_kills                       3.487092e-01
# r2_deaths                      3.635503e-01
# r2_items                       8.275584e+00
# r3_hero                        5.271049e+01
# r3_level                       3.353924e+00
# ...

# %%
data[data['radiant_win']].mean() < data.mean()
# Out:
# match_id                       False
# start_time                     False
# lobby_type                      True
# r1_hero                        False
# r1_level                       False
# r1_xp                          False
# r1_gold                        False
# r1_lh                          False
# r1_kills                       False
# r1_deaths                       True
# r1_items                       False
# r2_hero                         True
# r2_level                       False
# r2_xp                          False
# r2_gold                        False
# r2_lh                          False
# r2_kills                       False
# r2_deaths                       True
# r2_items                       False
# r3_hero                        False
# r3_level                       False
# r3_xp                          False
# r3_gold                        False
# r3_lh                          False
# r3_kills                       False
# ...

# %%
data[:1]
# Out:
#        match_id  start_time  lobby_type  r1_hero  r1_level  r1_xp  r1_gold  \
# 36853     43378  1443997688           7       25         0   2534     1907
#
#        r1_lh  r1_kills  r1_deaths  r1_items  r2_hero  r2_level  r2_xp  \
# 36853     22         1          0         9      104         0   1304
#
#        r2_gold  r2_lh  r2_kills  r2_deaths  r2_items  r3_hero  r3_level  \
# 36853     1403     12         1          0         8       41         0
#
#        r3_xp  r3_gold  r3_lh  r3_kills  r3_deaths  r3_items  r4_hero  \
# 36853   1376     1551     22         0          0         3       87
#
#        r4_level  r4_xp  r4_gold  r4_lh  r4_kills  r4_deaths  r4_items  \
# 36853         0    777      624      4         0          0         9
#
#        r5_hero  r5_level  r5_xp  r5_gold  r5_lh  r5_kills  r5_deaths  \
# 36853       84         0    831      499      0         0          0
#
#        r5_items  d1_hero  d1_level  d1_xp  d1_gold  d1_lh  d1_kills  \
# ...

# %%
data.apply(np.max)
# Out:
# match_id                           114406
# start_time                     1450313370
# lobby_type                              7
# r1_hero                               112
# r1_level                                6
# r1_xp                                3319
# r1_gold                              4332
# r1_lh                                  47
# r1_kills                                8
# r1_deaths                               5
# r1_items                               34
# r2_hero                               112
# r2_level                                6
# r2_xp                                3234
# r2_gold                              4136
# r2_lh                                  44
# r2_kills                                8
# r2_deaths                               6
# r2_items                               33
# r3_hero                               112
# r3_level                                7
# r3_xp                                3115
# ...

# %%
data['radiant_win'] = data['radiant_win'].map({True:1, False:0})

# %%
data['radiant_win'].head()
# Out:
# 36853    0
# 18757    1
# 40180    0
# 40179    0
# 6037     0
# Name: radiant_win, dtype: int64

# %%
data['radiant_win'] = data['radiant_win'].replace({1:True, 0:False})

# %%
data['radiant_win'].head()
# Out:
# 36853    False
# 18757     True
# 40180    False
# 40179    False
# 6037     False
# Name: radiant_win, dtype: bool

# %%
pd.crosstab(data['radiant_win'], data['r1_level'])
# Out:
# r1_level       0     1     2      3      4      5    6
# radiant_win
# False        452  1076  8107  15417  13290   8374  100
# True         462  1013  8084  16239  13696  10642  278

# %%
pd.crosstab(data['radiant_win'], data['r1_level']).plot()
plt.show()

# %%
pd.crosstab(data['radiant_win'], data['r1_level']).plot.bar()
plt.show()

# %%
pd.crosstab(data['radiant_win'], data['r1_level'], normalize=True)
# Out:
# r1_level            0         1         2         3         4         5  \
# radiant_win
# False        0.004649  0.011067  0.083380  0.158562  0.136686  0.086126
# True         0.004752  0.010419  0.083143  0.167016  0.140862  0.109452
#
# r1_level            6
# radiant_win
# False        0.001028
# True         0.002859

# %%
data.pivot_table(['r1_level', 'r1_items', 'r1_lh'],'radiant_win', aggfunc='mean')
# Out:
#              r1_items  r1_level      r1_lh
# radiant_win
# False        8.133266  3.399927  10.716315
# True         8.399512  3.482366  11.710874

# %%
r_level = data['r1_level'] + data['r2_level'] + data['r3_level'] + data['r4_level'] + data['r5_level']
data.insert(loc=len(data.columns), column='r_level', value=r_level)
data.iloc[:,-5:].head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-532d7cf2e4c1> in <module>
#       1 r_level = data['r1_level'] + data['r2_level'] + data['r3_level'] + data['r4_level'] + data['r5_level']
# ----> 2 data.insert(loc=len(data.columns), column='r_level', value=r_level)
#
# D:\Prog\Anaconda\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3220         value = self._sanitize_column(column, value, broadcast=False)
#    3221         self._data.insert(loc, column, value,
# -> 3222                           allow_duplicates=allow_duplicates)
#    3223
#    3224     def assign(self, **kwargs):
#
# D:\Prog\Anaconda\lib\site-packages\pandas\core\internals.py in insert(self, loc, item, value, allow_duplicates)
#    4336         if not allow_duplicates and item in self.items:
# ...

# %%
data['d_level'] = data['d1_level'] + data['d2_level'] + data['d3_level'] + data['d4_level'] + data['d5_level']
data.iloc[:,-5:].head()
# Out:
#        tower_status_dire  barracks_status_radiant  barracks_status_dire  \
# 36853               1958                        0                    63
# 18757                  4                       63                     3
# 40180               2047                        0                    63
# 40179               1982                        0                    63
# 6037                1974                       48                    63
#
#        r_level  d_level
# 36853        0        0
# 18757        1        3
# 40180        0        0
# 40179        0        0
# 6037         3        3

# %%
data = data.drop(['r_level', 'd_level'], axis=1)
